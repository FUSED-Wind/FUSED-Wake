# %%
# %load_ext autoreload
# %matplotlib inline  
# %autoreload 
__author__ = 'ewan'
import numpy as np
# print '\nBackend:\n' + mpl.get_backend() + '\n'

import sys
sys.path.append("../src/") 

import WindFarm as wf
import WindTurbine as wt
#import matplotlib.pyplot as plt
from DWM_flowfield_farm import DWM_main_field_model
from DWM_init_dict import init
from math import pi, sqrt, isnan
from DWM_GClarsenPicks import get_Rw_NOJ, gaussN, get_Rw, get_R96, Ua, Ua_shear
import time
from scipy import io, interpolate
from DWM_misc import smooth, to_bool
import matplotlib.pylab as plt
import matplotlib._cntr as cntr
import multiprocessing


def sDWM(derating,**kwargs):
#     WD,WS,TI,WTcoord,WTG,HH,R,stab,accum,optim,
    WD = kwargs.get('WD')
    WS = kwargs.get('WS')
    TI = kwargs.get('TI') 
    WTcoord = kwargs.get('WTcoord') 
    WTG = kwargs.get('WTG') 
    HH = kwargs.get('HH') 
    R = kwargs.get('R') 
    stab = kwargs.get('stab') 
    accum = kwargs.get('accum') 
    optim = to_bool(kwargs.get('optim'))
    
#     print '************************** Run DWM model ******************'
#     print '***********************************************************'
#     print '***********************************************************'
    ttt = time.time()
    # WT = wt.WindTurbine('Vestas v80 2MW offshore','V80_2MW_offshore.dat',70,40)
    # WF = wf.WindFarm('Horns Rev 1','HR_coordinates.dat',WT)
    WT = wt.WindTurbine('Windturbine','../WT-data/'+WTG+'/'+WTG+'_PC.dat',HH,R)
    WF = wf.WindFarm('Windfarm',WTcoord,WT)
    if optim is True:
        print 'Performing optimization'
        WT.CP = np.load('../WT-data/'+WTG+'/'+WTG+'_CP.npy')
        WT.CT = np.load('../WT-data/'+WTG+'/'+WTG+'_CT.npy')
        WT.lambdaf3=WT.CP[:,:,0]
        WT.PITCH3=WT.CP[:,:,1]
        WT.CP3=WT.CP[:,:,2]
        WT.CT3=WT.CT[:,:,2]
        WT.CP3[WT.CP3>(16./27.)]=0
        WT.CP3[np.isnan(WT.CP3)]=0
        WT.CT3[np.isnan(WT.CT3)]=0
        WT.CPc = cntr.Cntr(WT.PITCH3,WT.lambdaf3,WT.CP3)
        WT.CTc=cntr.Cntr(WT.PITCH3,WT.lambdaf3,WT.CT3)
        # WT.CPcurve= np.load('WT-data/'+WTG+'/BEM/CPcurve.npy')
        # WT.CTcurve= np.load('WT-data/'+WTG+'/BEM/CTcurve.npy')
        # WT.getCTCP= interpolator(WT.CPcurve,WT.CTcurve)
    elif optim is False:
        print 'Not Performing optimization'
        derating=1.0*np.ones((WF.nWT))
        WT.CP = None
        WT.CT = None

#     print 'Derating are', derating
    #WT = wt.WindTurbine('NREL 5 MW','NREL_5MW.dat',90,63.0)

    # Scaling wind farm to NREL's rotor size
    if 'Lill' in WTcoord:
        WF.vectWTtoWT=WF.vectWTtoWT*(WT.R/46.5) # 46.5 is the Lillgrund nominal radius of SWT turbine
    # Compute distance WT to WT in mean flow coordinate system
    distFlowCoord, nDownstream, id0= WF.turbineDistance(WD)

    # Init dictionnaries
    deficits, turb, inlets_ffor, inlets_ffor_deficits,inlets_ffor_turb,out, DWM, ID_waked, ID_wake_adj, Farm_p_out, WT_p_out, Vel_out,WT_pitch_out,WT_RPM_out=init(WF)

    # Extreme wake to define WT's in each wake, including partial wakes
    ID_wake = {id0[i]:(get_Rw(x=distFlowCoord[0,id0[i],:],\
                              R=2.*WF.WT.R,TI=TI,CT=WT.get_CT(WS),pars=[0.435449861,0.797853685,-0.124807893,0.136821858,15.6298,1.0])>\
               np.abs(distFlowCoord[1,id0[i],:])).nonzero()[0] \
               for i in range(WF.nWT)}
    # Power output list
    Farm_p_out=0.
    WT_p_out=np.zeros((WF.nWT))
    WT_pitch_out=np.zeros((WF.nWT,2))
    WT_RPM_out=np.zeros((WF.nWT,2))
    Vel_out=np.zeros((WF.nWT))
    # print ID_wake
    # fig,ax=WF.plot(WT_num=True)
    # fig.hold('True')
    # plt.show()

    for iT in range(WF.nWT):
        # Define flow case geometry
        cWT = id0[iT]
        #Radial coordinates in cWT for wake affected WT's
        x=distFlowCoord[0,cWT,ID_wake[cWT]]
        C2C   = distFlowCoord[1,cWT,ID_wake[cWT]]

        index_orig=np.argsort(x)
        x=np.sort(x)
        row= ID_wake[id0[iT]][index_orig]
        C2C=C2C[index_orig]

        # Wrapping the DWM core model with I/O
        par={
         'WS':WS,
         'TI':TI,
         'atmo_stab':stab,
         'WTG':'NY2',      #'WTG':'NREL5MW',
         'WTG_spec': WT,
         'wtg_ind': row, # turbine index
         'hub_z':x/(2*WF.WT.R), # compute the flow field at downstream location of each downwind turbine !
         'hub_x': np.ceil((3*(max(abs(C2C))+WF.WT.R))/WF.WT.R)*0.5+C2C/(WF.WT.R), # lateral offset of each downwind turbine with respect to the most upstream turbine in the tree
         'C2C': C2C, # center 2 center distances between hubs
         'lx':np.ceil((3.*(max(abs(C2C))+WF.WT.R))/WF.WT.R), # length of the domain in lateral
         'ly':np.ceil((3.*(max(abs(C2C))+WF.WT.R))/WF.WT.R),  # length of the domain in longitudinal in D
         # 'wake_ind_setting':1,
         'accu_inlet': True,
         'derating': derating[row[0]],
         'optim': optim,
         'accu': accum, # type of wake accumulation
         'full_output': True # Flag for generating the complete output with velocity deficit
        }

        ID_wake_adj[str(id0[iT])]=row
        aero, meta, mfor, ffor, DWM, deficits,inlets_ffor,inlets_ffor_deficits, inlets_ffor_turb,turb, out,ID_waked = DWM_main_field_model(ID_waked,deficits,inlets_ffor,inlets_ffor_deficits,inlets_ffor_turb,turb,DWM,out,**par)
        # Total power
        Farm_p_out= Farm_p_out+out[str(meta.wtg_ind[0])][0] # based on BEM
        # Power by each turbine
        WT_p_out[iT]=out[str(meta.wtg_ind[0])][0]
        # Pitch and RPM
        WT_pitch_out[iT,0]=aero.PITCH
        WT_pitch_out[iT,1]=aero.PITCH_opt
        WT_RPM_out[iT,0]=aero.RPM
        WT_RPM_out[iT,1]=aero.RPM_opt
        Vel_out[iT]=out[str(meta.wtg_ind[0])][1]    
    elapsedttt = time.time() - ttt
    print 'Total run  for wind direction %i is %4.2f sec' %(WD,elapsedttt)
    # filename='outputs/dwm_WS_'+ str(WS) +'_dir_' + str(WD)+'_TI_' + str(TI)
    # filename.replace('.','_')
    # np.save(filename,out)
    # return aero, meta, mfor, ffor, DWM, deficits,inlets_ffor,inlets_ffor_deficits, turb, DWM, out, ID_waked, id0,ID_wake_adj
    print 'The farm production is: %4.2f kW, where each turbine is: %s' %(Farm_p_out,np.array_str(WT_p_out))
    # plt.close('all')
    return Farm_p_out,WT_p_out,WT_pitch_out,WT_RPM_out,Vel_out,DWM

    # filename='outputs/dwm_WS_'+ str(WS) +'_dir_' + str(WD)+'_TI_' + str(TI)
    # filename.replace('.','_')
    # np.save(filename,out)

# %%
inputs={'WD':120.0,
'WS':9.0,
'TI':0.06,
# WTcoord=''../data/Lill_A04B04C04.dat''
'WTcoord':'../data/Lill_A04.dat',
'WTG':'NY2',
# 'WTG':'NREL5MW',
'HH':65.0,
'R':46.5,
'stab':'N',
'accum':'dominant',
'optim':True}

WD = inputs.get('WD')
WS = inputs.get('WS')
TI = inputs.get('TI') 
WTcoord = inputs.get('WTcoord') 
WTG = inputs.get('WTG') 
HH = inputs.get('HH') 
R = inputs.get('R') 
stab = inputs.get('stab') 
accum = inputs.get('accum') 
optim = to_bool(inputs.get('optim'))
    
    
WT = wt.WindTurbine('Windturbine','../WT-data/'+WTG+'/'+WTG+'_PC.dat',HH,R)
WF = wf.WindFarm('Windfarm',WTcoord,WT)

# spec=pd.read_csv('WT-data/'+WTG+'/'+WTG+'_Spec.dat',delim_whitespace=True,names=['ws', 'rpm', 'pitch'], header=10)
# print spec

Pref,Tref,Pitchref,RPMref,Vel_outref,DWM= sDWM([1.,1.],**inputs)
# Out:
# Performing optimization
# Total run  for wind direction 120 is 0.53 sec
# The farm production is: 1814.54 kW, where each turbine is: [ 1386.81   427.73]

# %%
# %matplotlib inline 
import pandas as pd
coord=pd.read_csv('../data/Lill_A04.dat',delim_whitespace=True,names=['x', 'y'], header=0)
plt.figure()
plt.plot(coord['x'],coord['y'],'ko')
plt.grid('on')
plt.show()

# %%
# Investigate step response for very small variation of deratings
# vTI=[0.06,0.06,0.06,0.06,0.06,0.06,0.06,0.08,0.10,0.11,0.12,0.13,0.14,0.15,0.15,0.15,0.15,0.15,0.15,0.15,0.15,0.15]

# vDe=np.arange(0.05,0.62,0.001)
vDe=np.arange(0.01,0.63,0.005)
# vW=np.arange(4.,25.5,1.)
# vDe=np.asarray([0.50,0.75])
vW=np.array([9.,])
# Cs_out=np.zeros(  (   4.   ,    len(vW)  ,  len(vDe)  ))
# Ptot_out=np.zeros(  (   len(vW)  ,  len(vDe)  ))

Ptots=np.zeros((   len(vW)  ,  len(vDe)  ))
Trefs=np.zeros(( WF.nWT,   len(vW)  ,  len(vDe)  ))
Pitchs=np.zeros(( WF.nWT,  len(vW)  ,  len(vDe) ))
Pitchs_opt=np.zeros(( WF.nWT,  len(vW)  ,  len(vDe) ))
RPMs=np.zeros(( WF.nWT,  len(vW)  ,  len(vDe) ))
RPMs_opt=np.zeros(( WF.nWT,  len(vW)  ,  len(vDe) ))
Vels_out=np.zeros(( WF.nWT,  len(vW)  ,  len(vDe) ))
DWMs=[l for l in range(len(vDe))]
TI=0.06
k1=0
for iWS in vW:
    k2=0
    for iDe in vDe:
        inputs={'WD':120.0,
        'WS':iWS,
#         'TI':vTI[int(iWS)-4],
        'TI':TI,
        # WTcoord='Lill_coordinates.dat'
        'WTcoord':'../data/Lill_A04.dat',
        'WTG':'NY2',
        'HH':65.0,
        'R':46.5,
        'stab':'N',
        'accum':'dominant',
        'optim':True}
        derating=[iDe,1.]
        print 'Run %s at wind speed %4.2f' %(derating,iWS)
        Pref,Tref,Pitchref,RPMref,Vel_out,DWM= sDWM(derating,**inputs)
#         print C_out
        Ptots[k1,k2]=Pref
        Trefs[:,k1,k2]=Tref
        Pitchs[:,k1,k2]=Pitchref[:,0]
        Pitchs_opt[:,k1,k2]=Pitchref[:,1]
        RPMs[:,k1,k2]=RPMref[:,0]
        RPMs_opt[:,k1,k2]=RPMref[:,1]
        Vels_out[:,k1,k2]=Vel_out
        DWMs[k2]=DWM
        k2=k2+1
    k1=k1+1
# Out:
# Run [0.01, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 23.367446775
# Total run  for wind direction 120 is 1.45 sec
# The farm production is: 1348.37 kW, where each turbine is: [   23.07  1325.3 ]
# Run [0.014999999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 23.121353025
# Total run  for wind direction 120 is 1.65 sec
# The farm production is: 1352.86 kW, where each turbine is: [   34.56  1318.3 ]
# Run [0.019999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 22.87630615
# Total run  for wind direction 120 is 1.46 sec
# The farm production is: 1357.35 kW, where each turbine is: [   45.96  1311.39]
# Run [0.024999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 22.6292124
# Total run  for wind direction 120 is 1.62 sec
# The farm production is: 1361.84 kW, where each turbine is: [   57.41  1304.43]
# Run [0.029999999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 22.381165525
# Total run  for wind direction 120 is 1.64 sec
# The farm production is: 1366.33 kW, where each turbine is: [   68.93  1297.4 ]
# Run [0.034999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 22.13111865
# Total run  for wind direction 120 is 1.58 sec
# The farm production is: 1370.77 kW, where each turbine is: [   80.52  1290.25]
# Run [0.039999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 21.88411865
# Total run  for wind direction 120 is 1.64 sec
# The farm production is: 1375.05 kW, where each turbine is: [   91.96  1283.09]
# Run [0.044999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 21.632071775
# Total run  for wind direction 120 is 1.74 sec
# The farm production is: 1379.49 kW, where each turbine is: [  103.56  1275.93]
# Run [0.049999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 21.38311865
# Total run  for wind direction 120 is 1.63 sec
# The farm production is: 1383.82 kW, where each turbine is: [  114.94  1268.88]
# Run [0.054999999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 20.9348999
# Total run  for wind direction 120 is 1.80 sec
# The farm production is: 1388.01 kW, where each turbine is: [  126.45  1261.56]
# Run [0.059999999999999991, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 20.237540525
# Total run  for wind direction 120 is 1.94 sec
# The farm production is: 1392.05 kW, where each turbine is: [  138.06  1253.99]
# Run [0.064999999999999988, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 19.5979624
# Total run  for wind direction 120 is 1.99 sec
# The farm production is: 1396.12 kW, where each turbine is: [  149.45  1246.67]
# Run [0.069999999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 19.018790525
# Total run  for wind direction 120 is 2.05 sec
# The farm production is: 1400.24 kW, where each turbine is: [  161.08  1239.16]
# Run [0.074999999999999983, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 18.4709624
# Total run  for wind direction 120 is 2.05 sec
# The farm production is: 1404.50 kW, where each turbine is: [  172.56  1231.94]
# Run [0.079999999999999988, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 17.9817749
# Total run  for wind direction 120 is 2.09 sec
# The farm production is: 1408.82 kW, where each turbine is: [  183.93  1224.89]
# Run [0.084999999999999978, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 17.51193115
# Total run  for wind direction 120 is 2.10 sec
# The farm production is: 1413.28 kW, where each turbine is: [  195.57  1217.71]
# Run [0.089999999999999983, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 17.070571775
# Total run  for wind direction 120 is 2.19 sec
# The farm production is: 1417.78 kW, where each turbine is: [  207.11  1210.67]
# Run [0.094999999999999987, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 16.6682749
# Total run  for wind direction 120 is 2.19 sec
# The farm production is: 1422.20 kW, where each turbine is: [  218.43  1203.77]
# Run [0.099999999999999978, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 16.2786499
# Total run  for wind direction 120 is 2.46 sec
# The farm production is: 1426.64 kW, where each turbine is: [  229.93  1196.71]
# Run [0.10499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 15.9104624
# Total run  for wind direction 120 is 2.80 sec
# The farm production is: 1431.26 kW, where each turbine is: [  241.39  1189.87]
# Run [0.10999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 15.5647124
# Total run  for wind direction 120 is 4.10 sec
# The farm production is: 1436.01 kW, where each turbine is: [  253.07  1182.94]
# Run [0.11499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 15.23468115
# Total run  for wind direction 120 is 2.91 sec
# The farm production is: 1440.70 kW, where each turbine is: [  264.47  1176.23]
# Run [0.11999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 14.916321775
# Total run  for wind direction 120 is 2.69 sec
# The farm production is: 1445.43 kW, where each turbine is: [  275.89  1169.54]
# Run [0.12499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 14.61849365
# Total run  for wind direction 120 is 2.67 sec
# The farm production is: 1450.20 kW, where each turbine is: [  287.44  1162.76]
# Run [0.12999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 14.33043115
# Total run  for wind direction 120 is 2.41 sec
# The farm production is: 1454.79 kW, where each turbine is: [  298.92  1155.87]
# Run [0.13499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 14.0480874
# Total run  for wind direction 120 is 2.58 sec
# The farm production is: 1459.69 kW, where each turbine is: [  310.59  1149.1 ]
# Run [0.13999999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 13.783509275
# Total run  for wind direction 120 is 2.54 sec
# The farm production is: 1464.48 kW, where each turbine is: [  321.9   1142.58]
# Run [0.14499999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 13.5276499
# Total run  for wind direction 120 is 2.54 sec
# The farm production is: 1469.40 kW, where each turbine is: [  333.47  1135.93]
# Run [0.14999999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 13.277603025
# Total run  for wind direction 120 is 2.75 sec
# The farm production is: 1474.35 kW, where each turbine is: [  345.09  1129.26]
# Run [0.155, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 13.035415525
# Total run  for wind direction 120 is 2.90 sec
# The farm production is: 1479.25 kW, where each turbine is: [  356.61  1122.64]
# Run [0.15999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 12.80599365
# Total run  for wind direction 120 is 2.69 sec
# The farm production is: 1483.76 kW, where each turbine is: [  367.91  1115.85]
# Run [0.16499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 12.5803374
# Total run  for wind direction 120 is 2.98 sec
# The farm production is: 1488.79 kW, where each turbine is: [  379.61  1109.18]
# Run [0.16999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 12.3615874
# Total run  for wind direction 120 is 3.67 sec
# The farm production is: 1493.76 kW, where each turbine is: [  391.17  1102.59]
# Run [0.17499999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 12.148696775
# Total run  for wind direction 120 is 4.03 sec
# The farm production is: 1498.72 kW, where each turbine is: [  402.65  1096.07]
# Run [0.17999999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 11.94261865
# Total run  for wind direction 120 is 3.28 sec
# The farm production is: 1503.68 kW, where each turbine is: [  414.09  1089.59]
# Run [0.18499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 11.7463999
# Total run  for wind direction 120 is 3.13 sec
# The farm production is: 1508.58 kW, where each turbine is: [  425.39  1083.19]
# Run [0.18999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 11.5490874
# Total run  for wind direction 120 is 3.18 sec
# The farm production is: 1513.25 kW, where each turbine is: [  437.13  1076.12]
# Run [0.19499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 11.36068115
# Total run  for wind direction 120 is 2.80 sec
# The farm production is: 1518.18 kW, where each turbine is: [  448.43  1069.75]
# Run [0.19999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 11.17418115
# Total run  for wind direction 120 is 2.97 sec
# The farm production is: 1523.20 kW, where each turbine is: [  459.88  1063.32]
# Run [0.20499999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 10.99249365
# Total run  for wind direction 120 is 3.35 sec
# The farm production is: 1528.29 kW, where each turbine is: [  471.45  1056.84]
# Run [0.20999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 10.8167124
# Total run  for wind direction 120 is 4.65 sec
# The farm production is: 1533.36 kW, where each turbine is: [  482.92  1050.44]
# Run [0.21499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 10.643884275
# Total run  for wind direction 120 is 3.39 sec
# The farm production is: 1538.42 kW, where each turbine is: [  494.39  1044.03]
# Run [0.21999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 10.4709624
# Total run  for wind direction 120 is 3.23 sec
# The farm production is: 1543.24 kW, where each turbine is: [  506.13  1037.11]
# Run [0.22499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 10.30599365
# Total run  for wind direction 120 is 3.25 sec
# The farm production is: 1548.04 kW, where each turbine is: [  517.42  1030.62]
# Run [0.22999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 10.140884275
# Total run  for wind direction 120 is 3.02 sec
# The farm production is: 1553.31 kW, where each turbine is: [  529.13  1024.18]
# Run [0.23499999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.98168115
# Total run  for wind direction 120 is 3.06 sec
# The farm production is: 1558.58 kW, where each turbine is: [  540.64  1017.94]
# Run [0.23999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.824478025
# Total run  for wind direction 120 is 3.33 sec
# The farm production is: 1563.88 kW, where each turbine is: [  552.19  1011.69]
# Run [0.24499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.67318115
# Total run  for wind direction 120 is 4.74 sec
# The farm production is: 1569.03 kW, where each turbine is: [  563.4   1005.63]
# Run [0.24999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.5178374
# Total run  for wind direction 120 is 3.57 sec
# The farm production is: 1574.33 kW, where each turbine is: [ 575.16  999.17]
# Run [0.25499999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.3683999
# Total run  for wind direction 120 is 3.30 sec
# The farm production is: 1579.10 kW, where each turbine is: [ 586.59  992.51]
# Run [0.25999999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.224915525
# Total run  for wind direction 120 is 3.50 sec
# The farm production is: 1584.33 kW, where each turbine is: [ 597.83  986.5 ]
# Run [0.26499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 9.080384275
# Total run  for wind direction 120 is 3.12 sec
# The farm production is: 1589.69 kW, where each turbine is: [ 609.34  980.35]
# Run [0.26999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.93780615
# Total run  for wind direction 120 is 3.14 sec
# The farm production is: 1595.07 kW, where each turbine is: [ 620.84  974.23]
# Run [0.27499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.79718115
# Total run  for wind direction 120 is 3.23 sec
# The farm production is: 1600.43 kW, where each turbine is: [ 632.32  968.11]
# Run [0.27999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.65455615
# Total run  for wind direction 120 is 2.96 sec
# The farm production is: 1605.85 kW, where each turbine is: [ 644.17  961.68]
# Run [0.28499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.5198374
# Total run  for wind direction 120 is 3.39 sec
# The farm production is: 1610.83 kW, where each turbine is: [ 655.42  955.41]
# Run [0.28999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.3830249
# Total run  for wind direction 120 is 3.44 sec
# The farm production is: 1615.95 kW, where each turbine is: [ 667.16  948.79]
# Run [0.29499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.2502124
# Total run  for wind direction 120 is 5.27 sec
# The farm production is: 1621.33 kW, where each turbine is: [ 678.63  942.7 ]
# Run [0.29999999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 8.1213999
# Total run  for wind direction 120 is 4.04 sec
# The farm production is: 1626.60 kW, where each turbine is: [ 689.83  936.77]
# Run [0.30499999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.988540525
# Total run  for wind direction 120 is 3.94 sec
# The farm production is: 1632.09 kW, where each turbine is: [ 701.57  930.52]
# Run [0.30999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.86068115
# Total run  for wind direction 120 is 3.50 sec
# The farm production is: 1637.33 kW, where each turbine is: [ 712.93  924.4 ]
# Run [0.31499999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.730728025
# Total run  for wind direction 120 is 3.23 sec
# The farm production is: 1642.71 kW, where each turbine is: [ 724.63  918.08]
# Run [0.31999999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.6067749
# Total run  for wind direction 120 is 3.33 sec
# The farm production is: 1647.34 kW, where each turbine is: [ 735.93  911.41]
# Run [0.32499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.4817749
# Total run  for wind direction 120 is 3.28 sec
# The farm production is: 1652.77 kW, where each turbine is: [ 747.45  905.32]
# Run [0.32999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.35668115
# Total run  for wind direction 120 is 3.25 sec
# The farm production is: 1658.25 kW, where each turbine is: [ 759.07  899.18]
# Run [0.33499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.23568115
# Total run  for wind direction 120 is 3.71 sec
# The farm production is: 1663.44 kW, where each turbine is: [ 770.37  893.07]
# Run [0.33999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 7.1135874
# Total run  for wind direction 120 is 3.91 sec
# The farm production is: 1668.35 kW, where each turbine is: [ 781.88  886.47]
# Run [0.34499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.99249365
# Total run  for wind direction 120 is 5.25 sec
# The farm production is: 1673.25 kW, where each turbine is: [ 793.37  879.88]
# Run [0.34999999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.8693999
# Total run  for wind direction 120 is 3.87 sec
# The farm production is: 1677.84 kW, where each turbine is: [ 805.17  872.67]
# Run [0.35499999999999998, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.7512124
# Total run  for wind direction 120 is 3.85 sec
# The farm production is: 1682.50 kW, where each turbine is: [ 816.59  865.91]
# Run [0.35999999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.635071775
# Total run  for wind direction 120 is 4.39 sec
# The farm production is: 1687.30 kW, where each turbine is: [ 827.86  859.44]
# Run [0.36499999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.51525625041
# Total run  for wind direction 120 is 4.60 sec
# The farm production is: 1692.21 kW, where each turbine is: [ 839.57  852.64]
# Run [0.36999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.39738378216
# Total run  for wind direction 120 is 3.79 sec
# The farm production is: 1697.09 kW, where each turbine is: [ 851.16  845.93]
# Run [0.37499999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.284205405
# Total run  for wind direction 120 is 3.44 sec
# The farm production is: 1701.68 kW, where each turbine is: [ 862.33  839.35]
# Run [0.37999999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.16590938553
# Total run  for wind direction 120 is 3.37 sec
# The farm production is: 1706.00 kW, where each turbine is: [ 874.09  831.91]
# Run [0.38499999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 6.04973810351
# Total run  for wind direction 120 is 3.28 sec
# The farm production is: 1710.72 kW, where each turbine is: [ 885.69  825.03]
# Run [0.38999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.93744945269
# Total run  for wind direction 120 is 3.72 sec
# The farm production is: 1715.35 kW, where each turbine is: [ 896.96  818.39]
# Run [0.39499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.82191412962
# Total run  for wind direction 120 is 5.43 sec
# The farm production is: 1720.17 kW, where each turbine is: [ 908.61  811.56]
# Run [0.39999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.71025902
# Total run  for wind direction 120 is 3.98 sec
# The farm production is: 1724.76 kW, where each turbine is: [ 919.91  804.85]
# Run [0.40499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.59472504222
# Total run  for wind direction 120 is 3.61 sec
# The farm production is: 1729.17 kW, where each turbine is: [ 931.64  797.53]
# Run [0.40999999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.48446608671
# Total run  for wind direction 120 is 3.14 sec
# The farm production is: 1733.19 kW, where each turbine is: [ 942.87  790.32]
# Run [0.41499999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.36940142464
# Total run  for wind direction 120 is 3.53 sec
# The farm production is: 1737.96 kW, where each turbine is: [ 954.62  783.34]
# Run [0.41999999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.25744099357
# Total run  for wind direction 120 is 3.53 sec
# The farm production is: 1742.61 kW, where each turbine is: [ 966.08  776.53]
# Run [0.42499999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.14438009
# Total run  for wind direction 120 is 5.36 sec
# The farm production is: 1747.26 kW, where each turbine is: [ 977.67  769.59]
# Run [0.42999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 5.03186421035
# Total run  for wind direction 120 is 3.86 sec
# The farm production is: 1751.62 kW, where each turbine is: [ 989.21  762.41]
# Run [0.43499999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.91976071379
# Total run  for wind direction 120 is 3.82 sec
# The farm production is: 1756.14 kW, where each turbine is: [ 1000.69   755.45]
# Run [0.43999999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.80803801
# Total run  for wind direction 120 is 3.77 sec
# The farm production is: 1760.97 kW, where each turbine is: [ 1012.14   748.83]
# Run [0.44499999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.69883426865
# Total run  for wind direction 120 is 3.47 sec
# The farm production is: 1765.99 kW, where each turbine is: [ 1023.33   742.66]
# Run [0.44999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.58563379
# Total run  for wind direction 120 is 5.00 sec
# The farm production is: 1771.10 kW, where each turbine is: [ 1034.89   736.21]
# Run [0.45499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.47207855758
# Total run  for wind direction 120 is 3.88 sec
# The farm production is: 1776.14 kW, where each turbine is: [ 1046.46   729.68]
# Run [0.45999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.35658306957
# Total run  for wind direction 120 is 3.38 sec
# The farm production is: 1781.18 kW, where each turbine is: [ 1058.18   723.  ]
# Run [0.46499999999999991, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.24585001581
# Total run  for wind direction 120 is 3.55 sec
# The farm production is: 1785.76 kW, where each turbine is: [ 1069.4    716.36]
# Run [0.46999999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.12880068426
# Total run  for wind direction 120 is 3.30 sec
# The farm production is: 1790.70 kW, where each turbine is: [ 1081.15   709.55]
# Run [0.47499999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 4.01644642368
# Total run  for wind direction 120 is 3.28 sec
# The farm production is: 1795.73 kW, where each turbine is: [ 1092.37   703.36]
# Run [0.47999999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.899876375
# Total run  for wind direction 120 is 3.98 sec
# The farm production is: 1799.65 kW, where each turbine is: [ 1103.87   695.78]
# Run [0.48499999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.77892507474
# Total run  for wind direction 120 is 4.72 sec
# The farm production is: 1803.21 kW, where each turbine is: [ 1115.64   687.57]
# Run [0.48999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.65925292449
# Total run  for wind direction 120 is 3.74 sec
# The farm production is: 1806.42 kW, where each turbine is: [ 1127.17   679.25]
# Run [0.49499999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.54132042909
# Total run  for wind direction 120 is 3.58 sec
# The farm production is: 1810.01 kW, where each turbine is: [ 1138.42   671.59]
# Run [0.49999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.41671402
# Total run  for wind direction 120 is 3.18 sec
# The farm production is: 1813.74 kW, where each turbine is: [ 1150.14   663.6 ]
# Run [0.50499999999999989, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.2961635545
# Total run  for wind direction 120 is 3.54 sec
# The farm production is: 1817.21 kW, where each turbine is: [ 1161.39   655.82]
# Run [0.5099999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.16972470441
# Total run  for wind direction 120 is 3.27 sec
# The farm production is: 1820.42 kW, where each turbine is: [ 1172.9    647.52]
# Run [0.5149999999999999, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 3.03843915291
# Total run  for wind direction 120 is 3.42 sec
# The farm production is: 1823.48 kW, where each turbine is: [ 1184.6    638.88]
# Run [0.51999999999999991, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.90917645192
# Total run  for wind direction 120 is 3.14 sec
# The farm production is: 1826.88 kW, where each turbine is: [ 1195.95   630.93]
# Run [0.52499999999999991, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.77335802
# Total run  for wind direction 120 is 3.29 sec
# The farm production is: 1830.05 kW, where each turbine is: [ 1207.62   622.43]
# Run [0.52999999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.63666501689
# Total run  for wind direction 120 is 3.45 sec
# The farm production is: 1833.54 kW, where each turbine is: [ 1219.15   614.39]
# Run [0.53499999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.49956260636
# Total run  for wind direction 120 is 3.22 sec
# The farm production is: 1837.49 kW, where each turbine is: [ 1230.47   607.02]
# Run [0.53999999999999992, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.35711090333
# Total run  for wind direction 120 is 3.60 sec
# The farm production is: 1842.02 kW, where each turbine is: [ 1241.94   600.08]
# Run [0.54499999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.21044945532
# Total run  for wind direction 120 is 3.43 sec
# The farm production is: 1846.53 kW, where each turbine is: [ 1253.41   593.12]
# Run [0.54999999999999993, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.05582641182
# Total run  for wind direction 120 is 5.63 sec
# The farm production is: 1848.47 kW, where each turbine is: [ 1265.06   583.41]
# Run [0.55499999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.89541163405
# Total run  for wind direction 120 is 4.04 sec
# The farm production is: 1849.27 kW, where each turbine is: [ 1276.62   572.65]
# Run [0.55999999999999994, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.72832290143
# Total run  for wind direction 120 is 3.83 sec
# The farm production is: 1850.55 kW, where each turbine is: [ 1288.06   562.49]
# Run [0.56499999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.55157557027
# Total run  for wind direction 120 is 3.70 sec
# The farm production is: 1851.61 kW, where each turbine is: [ 1299.49   552.12]
# Run [0.56999999999999995, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.36093039316
# Total run  for wind direction 120 is 5.30 sec
# The farm production is: 1852.27 kW, where each turbine is: [ 1311.06   541.21]
# Run [0.57499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.14110339783
# Total run  for wind direction 120 is 3.83 sec
# The farm production is: 1853.12 kW, where each turbine is: [ 1322.46   530.66]
# Run [0.57999999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.912998701724
# Total run  for wind direction 120 is 3.61 sec
# The farm production is: 1855.51 kW, where each turbine is: [ 1333.89   521.62]
# Run [0.58499999999999996, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.628184968462
# Total run  for wind direction 120 is 5.20 sec
# The farm production is: 1849.30 kW, where each turbine is: [ 1345.57   503.73]
# Run [0.58999999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.348660800763
# Total run  for wind direction 120 is 4.51 sec
# The farm production is: 1847.11 kW, where each turbine is: [ 1356.99   490.12]
# Run [0.59499999999999997, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.0217538989916
# Total run  for wind direction 120 is 3.86 sec
# The farm production is: 1845.00 kW, where each turbine is: [ 1368.56   476.44]
# Run [0.59999999999999987, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.574124895
# Total run  for wind direction 120 is 4.05 sec
# The farm production is: 1831.56 kW, where each turbine is: [ 1380.05   451.51]
# Run [0.60499999999999987, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 0.82 sec
# The farm production is: 1814.54 kW, where each turbine is: [ 1386.81   427.73]
# Run [0.60999999999999988, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.33 sec
# The farm production is: 1814.54 kW, where each turbine is: [ 1386.81   427.73]
# Run [0.61499999999999988, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.77 sec
# The farm production is: 1814.54 kW, where each turbine is: [ 1386.81   427.73]
# Run [0.61999999999999988, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.98 sec
# The farm production is: 1814.54 kW, where each turbine is: [ 1386.81   427.73]
# Run [0.62499999999999989, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.37 sec
# The farm production is: 1814.54 kW, where each turbine is: [ 1386.81   427.73]

# %%
dT1=np.asarray([])

for iT1 in vDe:
        dT1=np.append(dT1,iT1)

Ptotsf=Ptots.flatten()
Trefsf=Trefs.flatten()

# print '2d index', np.asarray(np.unravel_index(Ptots.argmax(), Ptots.shape))
opt_index= np.asarray(np.unravel_index(Ptots.argmax(), Ptots.shape))
print opt_index
Gainpower= 100*((max(Ptotsf)-Pref)/max(Ptotsf))
# print Trefs[:,opt_index[0],opt_index[1]]


# print dT1.shape
print 'Maximum power from optimization %4.2f/ max CP power %4.2f' %(max(Ptotsf) , Pref)
# print 'index', np.argmax(Ptotsf)
print 'Derating T1 at max power', dT1[np.argmax(Ptotsf)]
print 'Derating T1 at max cp', Tref[0]/WT.P_rated
print 'percentage of derating T1 at max power', 100*((Tref[0]/WT.P_rated-dT1[np.argmax(Ptotsf)])/(Tref[0]/WT.P_rated))
print 'Power yield gained from derating in %', Gainpower
print ' .... Power produced by 2 turbines at standard', Tref
print ' .... .Optimized power producted by 2 turbines', Trefs[:,opt_index[0],opt_index[1]]
# Out:
# [  0 114]
# Maximum power from optimization 1855.51/ max CP power 1814.54
# Derating T1 at max power 0.58
# Derating T1 at max cp 0.602949832962
# percentage of derating T1 at max power 3.80625911264
# Power yield gained from derating in % 2.20801828069
#  .... Power produced by 2 turbines at standard [ 1386.81   427.73]
#  .... .Optimized power producted by 2 turbines [ 1333.89   521.62]

# %%
# plot the stuff
# %matplotlib inline  
import bokeh
from bokeh.plotting import figure, show
bokeh.plotting.output_notebook()

# bokeh.plotting.output_file("layout.html")
# vDe=np.arange(0.125,1.25,0.125)
# vW=np.arange(4.,25.,0.25)
import colorsys
N= len(vDe)
HSV_tuples = [(xx*1.0/N, 0.5, 0.5) for xx in range(N)]
RGB_tuples = map(lambda x: colorsys.hsv_to_rgb(*x), HSV_tuples)
markers=['o','+','<','s','>','D','v','.']


# print Pitchs.shape
# plt.figure(figsize=(18,12))
# plt.subplot(2,2,1)
# p1 = figure(plot_width=250, plot_height=250)
# p1.line(100*(1.-(vDe/vDe[-1])),RPMs[0,0,:])      
# p1.circle(100*(1.-(vDe/vDe[-1])),RPMs[0,0,:], fill_color="white", size=8) 
# p1.line(100*(1.-(vDe/vDe[-1])),RPMs[1,0,:], color="olive")  
# p1.circle(100*(1.-(vDe/vDe[-1])),RPMs[1,0,:], color="olive", fill_color="white", size=8) 

#     plt.plot(vW,RPMs[1,:,k1],marker=None,color=RGB_tuples[k1] )      
# plt.plot(vW,RPMs_opt[0,:,0],'k--',label='Std')
# p.title('Control strategy RPM derating',fontsize=16)
# p.ylabel('RPM [-] ',fontsize=16)
# p.xlabel('Derating T1 [-]',fontsize=16)
# p.grid('on')
# p.legend(loc=2)


# p2 = figure(plot_width=250, plot_height=250)
# p2.line(100.*(1.-(vDe/vDe[-1])),Pitchs[0,0,:]) 
# p2.circle(100.*(1.-(vDe/vDe[-1])),Pitchs[0,0,:], fill_color="white", size=8) 
# p2.line(100.*(1.-(vDe/vDe[-1])),Pitchs[1,0,:], color="olive")  
# p2.circle(100.*(1.-(vDe/vDe[-1])),Pitchs[1,0,:],  color="olive",fill_color="white", size=8) 

#     plt.plot(vW,Pitchs[1,:,k1],marker=None,color=RGB_tuples[k1])     
# plt.plot(np.arange(4.,25.,0.5),Cs_out[3,:,0],'k--',label='Std')
# plt.title('Control strategy pitch derating',fontsize=16)
# plt.ylabel('Pitch [deg] ',fontsize=16)
# plt.xlabel('Derating T1 [-]',fontsize=16)
# plt.grid('on')
# plt.legend(loc=2)

# plt.subplot(2,2,3)

# for iP in vDe:
# p3 = figure(plot_width=250, plot_height=250)
# p3.line(100.*(1.-(vDe/vDe[-1])),Trefs[0,0,:])    
# p3.circle(100.*(1.-(vDe/vDe[-1])),Trefs[0,0,:], fill_color="white", size=8) 
# p3.line(100.*(1.-(vDe/vDe[-1])),Trefs[1,0,:], color="olive")
# p3.circle(100.*(1.-(vDe/vDe[-1])),Trefs[1,0,:], color="olive",fill_color="white", size=8) 
# p3.line(100.*(1.-(vDe/vDe[-1])),Ptots[0,:], color="red")
# p3.circle(100.*(1.-(vDe/vDe[-1])),Ptots[0,:], color="red",fill_color="white", size=8) 
# p = bokeh.io.gridplot([[p1, p2], [None, p3]])
# bokeh.plotting.show(p3)


## plot with axial induction

plt.figure()
# plt.subplot(1,3,1)
plt.plot([DWMs[l]['0'].mean_a for l in range(len(vDe))],Trefs[0,0,:]/Trefs[0,0,0],label='PT1')
plt.plot([DWMs[l]['0'].mean_a for l in range(len(vDe))],Trefs[1,0,:]/Trefs[0,0,0],label='PT2')
plt.plot([DWMs[l]['0'].mean_a for l in range(len(vDe))],Ptots[0,:]/Trefs[0,0,0],label='Ptots')
plt.plot([DWMs[l]['0'].mean_a for l in range(len(vDe))][np.argmax(Ptots[0,:])],np.amax(Ptots[0,:])/Trefs[0,0,0],'ks')
plt.xlabel('Axial induction factor of upstream turbine [-]')
plt.ylabel('Power [kW]')
plt.legend( loc=5)
plt.grid('on')

print [DWMs[l]['0'].mean_a for l in range(len(vDe))][np.argmax(Ptots[0,:])]


# plt.subplot(1,3,2)
# plt.plot()

# plt.hold(True)
#     plt.plot(vW,Trefs[1,:,k1],marker=None,color=RGB_tuples[k1])  
# plt.plot(np.arange(4.,25.,0.5),Cs_out[3,:,0],'k--',label='Std')
# plt.title('Derating: uptream power',fontsize=16)
# plt.ylabel('Power [kW] ',fontsize=16)
# plt.xlabel('Derating T1 [-]',fontsize=16)
# plt.grid('on')
# plt.legend(loc=2)

# plt.subplot(2,2,4)
# plt.plot(vW,Vels_out[0,:,1]-Vels_out[0,:,1],'k+',label='Std'  )      
# for iP in vDe:
# p= figure(plot_width=250, plot_height=400)
# p.line(100.*(1.-(vDe/vDe[-1])),100*(Vels_out[0,0,1]-Vels_out[1,0,:])/Vels_out[0,0,1]  )     
# p.circle(100.*(1.-(vDe/vDe[-1])),100*(Vels_out[0,0,1]-Vels_out[1,0,:])/Vels_out[0,0,1] , fill_color="white", size=8)
# bokeh.plotting.show(p)

# p = figure(plot_width=400, plot_height=400)
# p.line(100.*(1.-(vDe/vDe[-1])),Vels_out[1,0,:] )
# p.circle(100.*(1.-(vDe/vDe[-1])),Vels_out[1,0,:] , fill_color="white", size=8)
# bokeh.plotting.show(p)

# print Ptots.shape
# p = figure(plot_width=400, plot_height=400)
# p.line(100.*(1.-(vDe/vDe[-1])),Ptots[0,:] )
# p.circle(100.*(1.-(vDe/vDe[-1])),Ptots[0,:] , fill_color="white", size=8)
# bokeh.plotting.show(p)


# p = figure(plot_width=400, plot_height=400)
# p.line(vDe,Vels_out[1,0,:] )
# p.circle(vDe,Vels_out[1,0,:] , fill_color="white", size=8)
# bokeh.plotting.show(p)

# p = figure(plot_width=400, plot_height=400)
# p.line(vDe,Ptots[0,:]  )
# p.circle(vDe,Ptots[0,:] , fill_color="white", size=8)
# bokeh.plotting.show(p)
# plt.hold(True)
# plt.plot(np.arange(4.,25.,0.5),Cs_out[3,:,0],'k--',label='Std')
# plt.title('Derating: equivalent rotor velocity ratio',fontsize=16)
# plt.ylabel('(U0-VelT2)/U0 [%] ',fontsize=16)
# plt.xlabel('Derating T1 [-]',fontsize=16)
# plt.grid('on')
# plt.legend(loc=3)

# plt.savefig('Figs/ControlstrategyPitchRPM.png')
# plt.savefig('Figs/ControlstrategyPitchRPM.pdf')

# #
# lambda_der=np.zeros ((len(vW) , len(vDe)))

# k1=0
# for iWS in vW:
#     k2=0
#     for iDe in vDe:
#         lambda_der[k1,k2]=(pi*RPMs[0,k1,k2]*WT.R)/(30*vW[k1])
#         k2=k2+1
#     k1=k1+1
    
# plt.figure()
# plt.plot(vW,lambda_der[:,-1])
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
# 0.241098739969

# %%
inputs={'WD':120.0,
'WS':9.0,
'TI':0.06,
'WTcoord':'../data/Lill_A04B04C04.dat',
# 'WTcoord':'Lill_one_wt.dat',
'WTG':'NY2',
# 'WTG':'NREL5MW',
'HH':65.0,
'R':46.5,
'stab':'N',
'accum':'dominant',
'optim':True}

WD = inputs.get('WD')
WS = inputs.get('WS')
TI = inputs.get('TI') 
WTcoord = inputs.get('WTcoord') 
WTG = inputs.get('WTG') 
HH = inputs.get('HH') 
R = inputs.get('R') 
stab = inputs.get('stab') 
accum = inputs.get('accum') 
optim = to_bool(inputs.get('optim'))
    
    
WT = wt.WindTurbine('Windturbine','../WT-data/'+WTG+'/'+WTG+'_PC.dat',HH,R)
WF = wf.WindFarm('Windfarm',WTcoord,WT)

# spec=pd.read_csv('WT-data/'+WTG+'/'+WTG+'_Spec.dat',delim_whitespace=True,names=['ws', 'rpm', 'pitch'], header=10)
# print spec

# %%
# vT1=np.arange(0.90*dmax[0],dmax[0]+0.005,0.005)
# print vT1.shape

# vT2=np.arange(0.80*dmax[1],1.1*dmax[1]+0.005,0.005)
# print vT2.shape

# %%
# with variation of 0.5% max

Pref,Tref,Pitchref,RPMref,Vel_outref,DWMref= sDWM([1.,1.,1.,],**inputs)
dmax=np.ones((WF.nWT))
for iWT in np.arange(0.,WF.nWT,1.):
    dmax[iWT]=Tref[iWT]/WT.P_rated
Prefm,Trefm,Pitchrefm,RPMrefm,Vel_outm,DWMm= sDWM(dmax,**inputs)

print 'Prefm', Prefm
print 'Pref', Pref
print 'Trefm', Trefm
print 'Tref', Tref
print 'dmaxs', dmax
print 'Vel_outm', Vel_outm
print 'WT.P_rated',WT.P_rated

Pref=WF.nWT*WT.P_rated

vT1=np.arange(0.90*dmax[0],dmax[0]+0.005,0.005)
vT2=np.arange(0.90*dmax[1],1.15*dmax[1]+0.005,0.005)
# vW=np.arange(4.,25.5,1.)


Ptotsi=np.zeros((len(vT1),len(vT2)))
Trefsi=np.zeros(( WF.nWT, len(vT1),len(vT2)))
Pitchsi=np.zeros(( WF.nWT, len(vT1),len(vT2)))
Pitchs_opti=np.zeros(( WF.nWT, len(vT1),len(vT2)))
RPMsi=np.zeros(( WF.nWT, len(vT1),len(vT2),))
RPMs_opti=np.zeros(( WF.nWT, len(vT1),len(vT2)))
Vels_outi=np.zeros(( WF.nWT, len(vT1),len(vT2)))
DWMsi=[[l for l in range(len(vT2))] for k in range(len(vT1)) ]
TI=0.06

k1=0
for iT1 in vT1:
    k2=0
    for iT2 in vT2:
        derating=[iT1,iT2,1.]
        print 'Run %s at wind speed %4.2f' %(derating,WS)
        Pref,Tref,Pitchref,RPMref,Vel_out,DWM= sDWM(derating,**inputs)
#         print C_out
        Ptotsi[k1,k2]=Pref
        Trefsi[:,k1,k2]=Tref
        Pitchsi[:,k1,k2]=Pitchref[:,0]
        Pitchs_opti[:,k1,k2]=Pitchref[:,1]
        RPMsi[:,k1,k2]=RPMref[:,0]
        RPMs_opti[:,k1,k2]=RPMref[:,1]
        Vels_outi[:,k1,k2]=Vel_out
        DWMsi[k1][k2]=DWM
        k2=k2+1
    k1=k1+1
# Out:
# Performing optimization
# Total run  for wind direction 120 is 2.99 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Performing optimization
# Total run  for wind direction 120 is 3.74 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Prefm 2128.21
# Pref 2128.21
# Trefm [ 1386.81   417.75   323.65]
# Tref [ 1386.81   417.75   323.65]
# dmaxs [ 0.60294983  0.18162711  0.14071482]
# Vel_outm [ 9.    6.03  5.54]
# WT.P_rated 2300.0421
# Run [0.54265484966557775, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 6.0354624
# Total run  for wind direction 120 is 16.58 sec
# The farm production is: 2155.23 kW, where each turbine is: [ 1248.23   375.91   531.09]
# Run [0.54265484966557775, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 5.76393115
# Total run  for wind direction 120 is 14.90 sec
# The farm production is: 2161.31 kW, where each turbine is: [ 1248.23   387.5    525.58]
# Run [0.54265484966557775, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 5.496353025
# Total run  for wind direction 120 is 16.30 sec
# The farm production is: 2167.53 kW, where each turbine is: [ 1248.23   399.02   520.28]
# Run [0.54265484966557775, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 5.23068115
# Total run  for wind direction 120 is 18.64 sec
# The farm production is: 2173.95 kW, where each turbine is: [ 1248.23   410.53   515.19]
# Run [0.54265484966557775, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 4.965103025
# Total run  for wind direction 120 is 18.26 sec
# The farm production is: 2180.54 kW, where each turbine is: [ 1248.23   422.06   510.25]
# Run [0.54265484966557775, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 4.70143115
# Total run  for wind direction 120 is 15.55 sec
# The farm production is: 2187.29 kW, where each turbine is: [ 1248.23   433.5    505.56]
# Run [0.54265484966557775, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 4.43480615
# Total run  for wind direction 120 is 15.15 sec
# The farm production is: 2194.30 kW, where each turbine is: [ 1248.23   445.02   501.05]
# Run [0.54265484966557775, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 4.1682749
# Total run  for wind direction 120 is 15.59 sec
# The farm production is: 2201.48 kW, where each turbine is: [ 1248.23   456.44   496.81]
# Run [0.54265484966557775, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 3.8928374
# Total run  for wind direction 120 is 15.36 sec
# The farm production is: 2199.34 kW, where each turbine is: [ 1248.23   468.05   483.06]
# Run [0.54265484966557775, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 3.6115874
# Total run  for wind direction 120 is 14.18 sec
# The farm production is: 2185.90 kW, where each turbine is: [ 1248.23   479.55   458.12]
# Run [0.54265484966557775, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.27701565087
# Python Pitch from cobyla is 3.3225249
# Total run  for wind direction 120 is 14.34 sec
# The farm production is: 2190.60 kW, where each turbine is: [ 1248.23   491.04   451.33]
# Run [0.54765484966557776, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 5.9124624
# Total run  for wind direction 120 is 13.18 sec
# The farm production is: 2162.84 kW, where each turbine is: [ 1259.68   375.93   527.23]
# Run [0.54765484966557776, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 5.64093115
# Total run  for wind direction 120 is 12.10 sec
# The farm production is: 2168.98 kW, where each turbine is: [ 1259.68   387.41   521.89]
# Run [0.54765484966557776, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 5.370446775
# Total run  for wind direction 120 is 12.39 sec
# The farm production is: 2175.34 kW, where each turbine is: [ 1259.68   398.93   516.73]
# Run [0.54765484966557776, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 5.09986865
# Total run  for wind direction 120 is 12.67 sec
# The farm production is: 2181.95 kW, where each turbine is: [ 1259.68   410.51   511.76]
# Run [0.54765484966557776, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 4.8303374
# Total run  for wind direction 120 is 11.80 sec
# The farm production is: 2188.70 kW, where each turbine is: [ 1259.68   422.06   506.96]
# Run [0.54765484966557776, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 4.56380615
# Total run  for wind direction 120 is 6.87 sec
# The farm production is: 2195.53 kW, where each turbine is: [ 1259.68   433.44   502.41]
# Run [0.54765484966557776, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 4.2932749
# Total run  for wind direction 120 is 6.94 sec
# The farm production is: 2202.82 kW, where each turbine is: [ 1259.68   444.92   498.22]
# Run [0.54765484966557776, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 4.0168374
# Total run  for wind direction 120 is 6.92 sec
# The farm production is: 2210.29 kW, where each turbine is: [ 1259.68   456.52   494.09]
# Run [0.54765484966557776, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 3.7365874
# Total run  for wind direction 120 is 7.12 sec
# The farm production is: 2196.03 kW, where each turbine is: [ 1259.68   468.     468.35]
# Run [0.54765484966557776, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 3.448571775
# Total run  for wind direction 120 is 7.12 sec
# The farm production is: 2191.81 kW, where each turbine is: [ 1259.68   479.43   452.7 ]
# Run [0.54765484966557776, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.12806393511
# Python Pitch from cobyla is 3.14674365
# Total run  for wind direction 120 is 7.18 sec
# The farm production is: 2199.80 kW, where each turbine is: [ 1259.68   491.01   449.11]
# Run [0.55265484966557776, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 5.74349365
# Total run  for wind direction 120 is 7.01 sec
# The farm production is: 2169.33 kW, where each turbine is: [ 1271.21   375.95   522.17]
# Run [0.55265484966557776, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 5.46905615
# Total run  for wind direction 120 is 9.15 sec
# The farm production is: 2175.63 kW, where each turbine is: [ 1271.21   387.39   517.03]
# Run [0.55265484966557776, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 5.19161865
# Total run  for wind direction 120 is 7.86 sec
# The farm production is: 2182.27 kW, where each turbine is: [ 1271.21   399.03   512.03]
# Run [0.55265484966557776, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 4.918228025
# Total run  for wind direction 120 is 6.62 sec
# The farm production is: 2189.04 kW, where each turbine is: [ 1271.21   410.54   507.29]
# Run [0.55265484966557776, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 4.646790525
# Total run  for wind direction 120 is 7.02 sec
# The farm production is: 2195.92 kW, where each turbine is: [ 1271.21   421.93   502.78]
# Run [0.55265484966557776, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 4.3713999
# Total run  for wind direction 120 is 7.04 sec
# The farm production is: 2203.12 kW, where each turbine is: [ 1271.21   433.42   498.49]
# Run [0.55265484966557776, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 4.093103025
# Total run  for wind direction 120 is 7.46 sec
# The farm production is: 2210.72 kW, where each turbine is: [ 1271.21   444.92   494.59]
# Run [0.55265484966557776, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 3.8068999
# Total run  for wind direction 120 is 7.19 sec
# The farm production is: 2202.05 kW, where each turbine is: [ 1271.21   456.51   474.33]
# Run [0.55265484966557776, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 3.51593115
# Total run  for wind direction 120 is 7.09 sec
# The farm production is: 2192.56 kW, where each turbine is: [ 1271.21   467.95   453.4 ]
# Run [0.55265484966557776, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 3.2111499
# Total run  for wind direction 120 is 8.20 sec
# The farm production is: 2200.36 kW, where each turbine is: [ 1271.21   479.53   449.62]
# Run [0.55265484966557776, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.97150645106
# Python Pitch from cobyla is 2.894790525
# Total run  for wind direction 120 is 9.51 sec
# The farm production is: 2208.92 kW, where each turbine is: [ 1271.21   491.03   446.68]
# Run [0.55765484966557777, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 5.576478025
# Total run  for wind direction 120 is 6.98 sec
# The farm production is: 2174.61 kW, where each turbine is: [ 1282.72   375.89   516.  ]
# Run [0.55765484966557777, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 5.293228025
# Total run  for wind direction 120 is 7.39 sec
# The farm production is: 2181.21 kW, where each turbine is: [ 1282.72   387.53   510.96]
# Run [0.55765484966557777, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 5.01693115
# Total run  for wind direction 120 is 12.59 sec
# The farm production is: 2187.89 kW, where each turbine is: [ 1282.72   398.94   506.23]
# Run [0.55765484966557777, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 4.7365874
# Total run  for wind direction 120 is 12.79 sec
# The farm production is: 2194.88 kW, where each turbine is: [ 1282.72   410.51   501.65]
# Run [0.55765484966557777, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 4.456290525
# Total run  for wind direction 120 is 13.14 sec
# The farm production is: 2202.06 kW, where each turbine is: [ 1282.72   422.02   497.32]
# Run [0.55765484966557777, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 4.1740874
# Total run  for wind direction 120 is 13.12 sec
# The farm production is: 2209.66 kW, where each turbine is: [ 1282.72   433.5    493.44]
# Run [0.55765484966557777, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 3.8880249
# Total run  for wind direction 120 is 12.88 sec
# The farm production is: 2207.34 kW, where each turbine is: [ 1282.72   444.95   479.67]
# Run [0.55765484966557777, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 3.590103025
# Total run  for wind direction 120 is 13.64 sec
# The farm production is: 2192.87 kW, where each turbine is: [ 1282.72   456.54   453.61]
# Run [0.55765484966557777, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 3.285415525
# Total run  for wind direction 120 is 13.44 sec
# The farm production is: 2199.37 kW, where each turbine is: [ 1282.72   468.04   448.61]
# Run [0.55765484966557777, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 2.96905615
# Total run  for wind direction 120 is 12.17 sec
# The farm production is: 2207.63 kW, where each turbine is: [ 1282.72   479.45   445.46]
# Run [0.55765484966557777, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.80732708813
# Python Pitch from cobyla is 2.635071775
# Total run  for wind direction 120 is 7.29 sec
# The farm production is: 2216.80 kW, where each turbine is: [ 1282.72   490.95   443.13]
# Run [0.56265484966557777, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 5.39974365
# Total run  for wind direction 120 is 6.89 sec
# The farm production is: 2181.59 kW, where each turbine is: [ 1294.21   375.92   511.46]
# Run [0.56265484966557777, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 5.112540525
# Total run  for wind direction 120 is 7.23 sec
# The farm production is: 2188.40 kW, where each turbine is: [ 1294.21   387.53   506.66]
# Run [0.56265484966557777, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 4.8293374
# Total run  for wind direction 120 is 7.18 sec
# The farm production is: 2195.31 kW, where each turbine is: [ 1294.21   399.     502.1 ]
# Run [0.56265484966557777, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 4.54418115
# Total run  for wind direction 120 is 7.19 sec
# The farm production is: 2202.59 kW, where each turbine is: [ 1294.21   410.53   497.85]
# Run [0.56265484966557777, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 4.25911865
# Total run  for wind direction 120 is 7.27 sec
# The farm production is: 2210.04 kW, where each turbine is: [ 1294.21   421.94   493.89]
# Run [0.56265484966557777, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 3.965103025
# Total run  for wind direction 120 is 7.28 sec
# The farm production is: 2214.42 kW, where each turbine is: [ 1294.21   433.55   486.66]
# Run [0.56265484966557777, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 3.6692749
# Total run  for wind direction 120 is 7.82 sec
# The farm production is: 2199.01 kW, where each turbine is: [ 1294.21   444.93   459.87]
# Run [0.56265484966557777, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 3.36068115
# Total run  for wind direction 120 is 7.71 sec
# The farm production is: 2199.95 kW, where each turbine is: [ 1294.21   456.45   449.29]
# Run [0.56265484966557777, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 3.04036865
# Total run  for wind direction 120 is 8.03 sec
# The farm production is: 2208.40 kW, where each turbine is: [ 1294.21   467.94   446.25]
# Run [0.56265484966557777, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 2.70143115
# Total run  for wind direction 120 is 7.77 sec
# The farm production is: 2217.58 kW, where each turbine is: [ 1294.21   479.49   443.88]
# Run [0.56265484966557777, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.63443393311
# Python Pitch from cobyla is 2.3449624
# Total run  for wind direction 120 is 8.04 sec
# The farm production is: 2227.69 kW, where each turbine is: [ 1294.21   491.     442.48]
# Run [0.56765484966557778, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 5.21224365
# Total run  for wind direction 120 is 7.32 sec
# The farm production is: 2188.78 kW, where each turbine is: [ 1305.69   375.94   507.15]
# Run [0.56765484966557778, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 4.92218115
# Total run  for wind direction 120 is 7.21 sec
# The farm production is: 2195.74 kW, where each turbine is: [ 1305.69   387.46   502.59]
# Run [0.56765484966557778, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 4.63111865
# Total run  for wind direction 120 is 7.39 sec
# The farm production is: 2203.00 kW, where each turbine is: [ 1305.69   399.     498.31]
# Run [0.56765484966557778, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 4.3411499
# Total run  for wind direction 120 is 10.73 sec
# The farm production is: 2210.46 kW, where each turbine is: [ 1305.69   410.44   494.33]
# Run [0.56765484966557778, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 4.04318115
# Total run  for wind direction 120 is 13.46 sec
# The farm production is: 2218.44 kW, where each turbine is: [ 1305.69   422.02   490.73]
# Run [0.56765484966557778, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 3.74049365
# Total run  for wind direction 120 is 13.41 sec
# The farm production is: 2204.95 kW, where each turbine is: [ 1305.69   433.5    465.76]
# Run [0.56765484966557778, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 3.42799365
# Total run  for wind direction 120 is 13.47 sec
# The farm production is: 2200.85 kW, where each turbine is: [ 1305.69   445.01   450.15]
# Run [0.56765484966557778, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 3.1057749
# Total run  for wind direction 120 is 13.63 sec
# The farm production is: 2209.04 kW, where each turbine is: [ 1305.69   456.45   446.9 ]
# Run [0.56765484966557778, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 2.76393115
# Total run  for wind direction 120 is 13.44 sec
# The farm production is: 2218.20 kW, where each turbine is: [ 1305.69   468.02   444.49]
# Run [0.56765484966557778, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 2.40655615
# Total run  for wind direction 120 is 13.62 sec
# The farm production is: 2228.21 kW, where each turbine is: [ 1305.69   479.45   443.07]
# Run [0.56765484966557778, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.45080351405
# Python Pitch from cobyla is 2.0168374
# Total run  for wind direction 120 is 13.92 sec
# The farm production is: 2214.48 kW, where each turbine is: [ 1305.69   491.01   417.78]
# Run [0.57265484966557778, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 5.01693115
# Total run  for wind direction 120 is 12.88 sec
# The farm production is: 2194.43 kW, where each turbine is: [ 1317.06   375.93   501.44]
# Run [0.57265484966557778, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 4.721009275
# Total run  for wind direction 120 is 12.37 sec
# The farm production is: 2201.64 kW, where each turbine is: [ 1317.06   387.43   497.15]
# Run [0.57265484966557778, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 4.42318115
# Total run  for wind direction 120 is 7.06 sec
# The farm production is: 2209.12 kW, where each turbine is: [ 1317.06   398.95   493.11]
# Run [0.57265484966557778, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 4.121353025
# Total run  for wind direction 120 is 7.20 sec
# The farm production is: 2217.13 kW, where each turbine is: [ 1317.06   410.53   489.54]
# Run [0.57265484966557778, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 3.8167124
# Total run  for wind direction 120 is 7.24 sec
# The farm production is: 2209.43 kW, where each turbine is: [ 1317.06   421.94   470.43]
# Run [0.57265484966557778, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 3.50030615
# Total run  for wind direction 120 is 7.26 sec
# The farm production is: 2199.68 kW, where each turbine is: [ 1317.06   433.42   449.2 ]
# Run [0.57265484966557778, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 3.17018115
# Total run  for wind direction 120 is 7.28 sec
# The farm production is: 2207.93 kW, where each turbine is: [ 1317.06   444.99   445.88]
# Run [0.57265484966557778, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 2.82843115
# Total run  for wind direction 120 is 7.22 sec
# The farm production is: 2216.95 kW, where each turbine is: [ 1317.06   456.45   443.44]
# Run [0.57265484966557778, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 2.4631499
# Total run  for wind direction 120 is 7.80 sec
# The farm production is: 2227.05 kW, where each turbine is: [ 1317.06   468.03   441.96]
# Run [0.57265484966557778, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 2.0755249
# Total run  for wind direction 120 is 8.08 sec
# The farm production is: 2221.83 kW, where each turbine is: [ 1317.06   479.45   425.32]
# Run [0.57265484966557778, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.24770849884
# Python Pitch from cobyla is 1.6380249
# Total run  for wind direction 120 is 10.63 sec
# The farm production is: 2209.00 kW, where each turbine is: [ 1317.06   490.96   400.98]
# Run [0.57765484966557779, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 4.83724365
# Total run  for wind direction 120 is 7.33 sec
# The farm production is: 2202.72 kW, where each turbine is: [ 1328.56   375.94   498.22]
# Run [0.57765484966557779, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 4.5354624
# Total run  for wind direction 120 is 7.33 sec
# The farm production is: 2210.24 kW, where each turbine is: [ 1328.56   387.43   494.25]
# Run [0.57765484966557779, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 4.2287749
# Total run  for wind direction 120 is 7.68 sec
# The farm production is: 2218.12 kW, where each turbine is: [ 1328.56   399.01   490.55]
# Run [0.57765484966557779, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 3.92218115
# Total run  for wind direction 120 is 7.47 sec
# The farm production is: 2218.98 kW, where each turbine is: [ 1328.56   410.43   479.99]
# Run [0.57765484966557779, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 3.60186865
# Total run  for wind direction 120 is 8.30 sec
# The farm production is: 2203.03 kW, where each turbine is: [ 1328.56   421.95   452.52]
# Run [0.57765484966557779, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 3.26974365
# Total run  for wind direction 120 is 8.01 sec
# The farm production is: 2209.24 kW, where each turbine is: [ 1328.56   433.52   447.16]
# Run [0.57765484966557779, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 2.9240874
# Total run  for wind direction 120 is 8.17 sec
# The farm production is: 2217.96 kW, where each turbine is: [ 1328.56   445.02   444.38]
# Run [0.57765484966557779, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 2.56280615
# Total run  for wind direction 120 is 10.13 sec
# The farm production is: 2227.81 kW, where each turbine is: [ 1328.56   456.46   442.79]
# Run [0.57765484966557779, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 2.1730874
# Total run  for wind direction 120 is 7.81 sec
# The farm production is: 2239.26 kW, where each turbine is: [ 1328.56   468.     442.7 ]
# Run [0.57765484966557779, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 1.74049365
# Total run  for wind direction 120 is 8.35 sec
# The farm production is: 2209.52 kW, where each turbine is: [ 1328.56   479.51   401.45]
# Run [0.57765484966557779, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.01691375005
# Python Pitch from cobyla is 1.2317749
# Total run  for wind direction 120 is 8.36 sec
# The farm production is: 2224.50 kW, where each turbine is: [ 1328.56   490.96   404.98]
# Run [0.58265484966557779, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 4.55499365
# Total run  for wind direction 120 is 7.46 sec
# The farm production is: 2207.93 kW, where each turbine is: [ 1340.16   375.96   491.81]
# Run [0.58265484966557779, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 4.24049365
# Total run  for wind direction 120 is 7.56 sec
# The farm production is: 2216.03 kW, where each turbine is: [ 1340.16   387.5    488.37]
# Run [0.58265484966557779, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 3.9220874
# Total run  for wind direction 120 is 7.41 sec
# The farm production is: 2216.98 kW, where each turbine is: [ 1340.16   399.01   477.81]
# Run [0.58265484966557779, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 3.5949624
# Total run  for wind direction 120 is 7.70 sec
# The farm production is: 2200.76 kW, where each turbine is: [ 1340.16   410.5    450.1 ]
# Run [0.58265484966557779, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 3.25411865
# Total run  for wind direction 120 is 7.80 sec
# The farm production is: 2207.44 kW, where each turbine is: [ 1340.16   422.01   445.27]
# Run [0.58265484966557779, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 2.89974365
# Total run  for wind direction 120 is 8.22 sec
# The farm production is: 2216.54 kW, where each turbine is: [ 1340.16   433.43   442.95]
# Run [0.58265484966557779, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 2.52374365
# Total run  for wind direction 120 is 9.43 sec
# The farm production is: 2226.74 kW, where each turbine is: [ 1340.16   444.93   441.65]
# Run [0.58265484966557779, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 2.117446775
# Total run  for wind direction 120 is 7.72 sec
# The farm production is: 2228.64 kW, where each turbine is: [ 1340.16   456.52   431.96]
# Run [0.58265484966557779, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 1.6682749
# Total run  for wind direction 120 is 7.73 sec
# The farm production is: 2209.21 kW, where each turbine is: [ 1340.16   467.96   401.09]
# Run [0.58265484966557779, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 1.11749365
# Total run  for wind direction 120 is 8.10 sec
# The farm production is: 2225.58 kW, where each turbine is: [ 1340.16   479.44   405.98]
# Run [0.58265484966557779, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.762625942637
# Python Pitch from cobyla is 0.3870249
# Total run  for wind direction 120 is 10.33 sec
# The farm production is: 2203.92 kW, where each turbine is: [ 1340.16   490.95   372.81]
# Run [0.58765484966557779, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 4.2287749
# Total run  for wind direction 120 is 7.55 sec
# The farm production is: 2215.31 kW, where each turbine is: [ 1351.6    376.04   487.67]
# Run [0.58765484966557779, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 3.9006499
# Total run  for wind direction 120 is 10.81 sec
# The farm production is: 2214.84 kW, where each turbine is: [ 1351.6    387.51   475.73]
# Run [0.58765484966557779, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 3.56380615
# Total run  for wind direction 120 is 13.57 sec
# The farm production is: 2198.68 kW, where each turbine is: [ 1351.6    398.93   448.15]
# Run [0.58765484966557779, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 3.21224365
# Total run  for wind direction 120 is 13.57 sec
# The farm production is: 2207.51 kW, where each turbine is: [ 1351.6    410.45   445.46]
# Run [0.58765484966557779, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 2.8411499
# Total run  for wind direction 120 is 13.68 sec
# The farm production is: 2216.80 kW, where each turbine is: [ 1351.6    421.94   443.26]
# Run [0.58765484966557779, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 2.447571775
# Total run  for wind direction 120 is 14.16 sec
# The farm production is: 2227.59 kW, where each turbine is: [ 1351.6    433.46   442.53]
# Run [0.58765484966557779, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 2.02174365
# Total run  for wind direction 120 is 14.07 sec
# The farm production is: 2215.13 kW, where each turbine is: [ 1351.6    444.99   418.54]
# Run [0.58765484966557779, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 1.539321775
# Total run  for wind direction 120 is 14.49 sec
# The farm production is: 2211.22 kW, where each turbine is: [ 1351.6    456.5    403.12]
# Run [0.58765484966557779, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 0.9338999
# Total run  for wind direction 120 is 14.29 sec
# The farm production is: 2228.74 kW, where each turbine is: [ 1351.6    467.96   409.18]
# Run [0.58765484966557779, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Python Pitch from cobyla is 0.06761865
# Total run  for wind direction 120 is 14.71 sec
# The farm production is: 2213.30 kW, where each turbine is: [ 1351.6    479.49   382.21]
# Run [0.58765484966557779, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.487233011972
# Total run  for wind direction 120 is 5.68 sec
# The farm production is: 2156.99 kW, where each turbine is: [ 1351.6    486.9    318.49]
# Run [0.5926548496655778, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 3.8880249
# Total run  for wind direction 120 is 6.99 sec
# The farm production is: 2212.11 kW, where each turbine is: [ 1363.17   375.93   473.01]
# Run [0.5926548496655778, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 3.5364624
# Total run  for wind direction 120 is 7.38 sec
# The farm production is: 2197.33 kW, where each turbine is: [ 1363.17   387.44   446.72]
# Run [0.5926548496655778, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 3.17218115
# Total run  for wind direction 120 is 7.13 sec
# The farm production is: 2206.14 kW, where each turbine is: [ 1363.17   398.93   444.04]
# Run [0.5926548496655778, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 2.78636865
# Total run  for wind direction 120 is 7.86 sec
# The farm production is: 2216.16 kW, where each turbine is: [ 1363.17   410.49   442.5 ]
# Run [0.5926548496655778, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 2.375259275
# Total run  for wind direction 120 is 7.77 sec
# The farm production is: 2227.51 kW, where each turbine is: [ 1363.17   422.01   442.33]
# Run [0.5926548496655778, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 1.92799365
# Total run  for wind direction 120 is 9.48 sec
# The farm production is: 2202.56 kW, where each turbine is: [ 1363.17   433.49   405.9 ]
# Run [0.5926548496655778, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 1.41136865
# Total run  for wind direction 120 is 8.97 sec
# The farm production is: 2212.59 kW, where each turbine is: [ 1363.17   444.99   404.43]
# Run [0.5926548496655778, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is 0.7307749
# Total run  for wind direction 120 is 7.76 sec
# The farm production is: 2188.46 kW, where each turbine is: [ 1363.17   456.45   368.84]
# Run [0.5926548496655778, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Python Pitch from cobyla is -0.33081885
# Total run  for wind direction 120 is 10.51 sec
# The farm production is: 2180.35 kW, where each turbine is: [ 1363.17   467.99   349.19]
# Run [0.5926548496655778, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Total run  for wind direction 120 is 4.40 sec
# The farm production is: 2153.79 kW, where each turbine is: [ 1363.17   471.8    318.82]
# Run [0.5926548496655778, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.145638571313
# Total run  for wind direction 120 is 3.95 sec
# The farm production is: 2153.79 kW, where each turbine is: [ 1363.17   471.8    318.82]
# Run [0.5976548496655778, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 3.370353025
# Total run  for wind direction 120 is 9.70 sec
# The farm production is: 2196.83 kW, where each turbine is: [ 1374.6    376.01   446.22]
# Run [0.5976548496655778, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 2.9787749
# Total run  for wind direction 120 is 8.43 sec
# The farm production is: 2206.29 kW, where each turbine is: [ 1374.6    387.52   444.17]
# Run [0.5976548496655778, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 2.568665525
# Total run  for wind direction 120 is 9.05 sec
# The farm production is: 2217.45 kW, where each turbine is: [ 1374.6    398.93   443.92]
# Run [0.5976548496655778, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 2.120353025
# Total run  for wind direction 120 is 9.82 sec
# The farm production is: 2220.34 kW, where each turbine is: [ 1374.6    410.5    435.24]
# Run [0.5976548496655778, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 1.6115874
# Total run  for wind direction 120 is 10.76 sec
# The farm production is: 2201.61 kW, where each turbine is: [ 1374.6    422.01   405.  ]
# Run [0.5976548496655778, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 0.9709624
# Total run  for wind direction 120 is 8.45 sec
# The farm production is: 2220.94 kW, where each turbine is: [ 1374.6    433.49   412.85]
# Run [0.5976548496655778, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Python Pitch from cobyla is 0.05499365
# Total run  for wind direction 120 is 10.54 sec
# The farm production is: 2205.75 kW, where each turbine is: [ 1374.6    444.97   386.18]
# Run [0.5976548496655778, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Total run  for wind direction 120 is 4.64 sec
# The farm production is: 2147.55 kW, where each turbine is: [ 1374.6    451.71   321.24]
# Run [0.5976548496655778, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Total run  for wind direction 120 is 4.42 sec
# The farm production is: 2147.55 kW, where each turbine is: [ 1374.6    451.71   321.24]
# Run [0.5976548496655778, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Total run  for wind direction 120 is 6.15 sec
# The farm production is: 2147.55 kW, where each turbine is: [ 1374.6    451.71   321.24]
# Run [0.5976548496655778, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -0.291223510585
# Total run  for wind direction 120 is 4.71 sec
# The farm production is: 2147.55 kW, where each turbine is: [ 1374.6    451.71   321.24]
# Run [0.60265484966557781, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Python Pitch from cobyla is 2.01293115
# Total run  for wind direction 120 is 7.80 sec
# The farm production is: 2183.54 kW, where each turbine is: [ 1386.12   375.99   421.43]
# Run [0.60265484966557781, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Python Pitch from cobyla is 1.43099365
# Total run  for wind direction 120 is 10.68 sec
# The farm production is: 2183.68 kW, where each turbine is: [ 1386.12   387.46   410.1 ]
# Run [0.60265484966557781, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Python Pitch from cobyla is 0.625259275
# Total run  for wind direction 120 is 9.28 sec
# The farm production is: 2161.79 kW, where each turbine is: [ 1386.12   398.99   376.68]
# Run [0.60265484966557781, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Python Pitch from cobyla is -0.88550635
# Total run  for wind direction 120 is 10.31 sec
# The farm production is: 2131.16 kW, where each turbine is: [ 1386.12   410.48   334.56]
# Run [0.60265484966557781, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 4.45 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60265484966557781, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 6.10 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60265484966557781, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 4.52 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60265484966557781, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 4.04 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60265484966557781, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 4.27 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60265484966557781, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 4.36 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60265484966557781, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is -1.76237022583
# Total run  for wind direction 120 is 6.13 sec
# The farm production is: 2122.13 kW, where each turbine is: [ 1386.12   411.19   324.82]
# Run [0.60765484966557781, 0.16346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 2.2756499
# Total run  for wind direction 120 is 5.50 sec
# The farm production is: 2208.67 kW, where each turbine is: [ 1386.81   376.02   445.84]
# Run [0.60765484966557781, 0.16846439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.7522124
# Total run  for wind direction 120 is 5.02 sec
# The farm production is: 2179.92 kW, where each turbine is: [ 1386.81   387.48   405.63]
# Run [0.60765484966557781, 0.17346439919512779, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 1.101821775
# Total run  for wind direction 120 is 5.51 sec
# The farm production is: 2199.38 kW, where each turbine is: [ 1386.81   399.     413.57]
# Run [0.60765484966557781, 0.1784643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Python Pitch from cobyla is 0.160415525
# Total run  for wind direction 120 is 5.26 sec
# The farm production is: 2183.92 kW, where each turbine is: [ 1386.81   410.49   386.62]
# Run [0.60765484966557781, 0.1834643991951278, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.31 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Run [0.60765484966557781, 0.18846439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.97 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Run [0.60765484966557781, 0.19346439919512781, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.94 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Run [0.60765484966557781, 0.19846439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.35 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Run [0.60765484966557781, 0.20346439919512782, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.36 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Run [0.60765484966557781, 0.20846439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.34 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# Run [0.60765484966557781, 0.21346439919512783, 1.0] at wind speed 9.00
# Performing optimization
# Total run  for wind direction 120 is 1.23 sec
# The farm production is: 2128.21 kW, where each turbine is: [ 1386.81   417.75   323.65]
# /home/ewan/Work/PostDoc/DWMstandalone/sDWM-WFC/venvDWMWFC/lib/python2.7/site-packages/ipykernel/__main__.py:6: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
# np.save('outputs/deratingTesting/Ptots.npy',Ptotsi)
# np.save('outputs/deratingTesting/Trefs.npy',Trefsi)
# np.save('outputs/deratingTesting/Pitchs.npy',Pitchsi)
# np.save('outputs/deratingTesting/Pitchs_opt3.npy',Pitchs_opti)
# np.save('outputs/deratingTesting/RPMs.npy',RPMsi)
# np.save('outputs/deratingTesting/RPMs_opt.npy',RPMs_opti)
# np.save('outputs/deratingTesting/Vels_opt.npy',Vels_outi)
# np.save('outputs/deratingTesting/vT1_opt',vT1)
# np.save('outputs/deratingTesting/vT2_opt.npy',vT2)
# np.save('outputs/deratingTesting/Pref.npy',Pref)
# np.save('outputs/deratingTesting/Tref.npy',Tref)
# np.save('outputs/deratingTesting/Pitchref.npy',Pitchref)
# np.save('outputs/deratingTesting/RPMref.npy',RPMref)
# np.save('outputs/deratingTesting/Vel_outref.npy',Vel_outref)
# np.save('outputs/deratingTesting/dmax.npy',dmax)

# %%
dT1=np.asarray([])
dT2=np.asarray([])
# dT3=np.asarray([])
for iT1 in vT1:
    for iT2 in vT2:
#         for iT3 in np.arange(0.06,0.71,0.05):
        dT1=np.append(dT1,iT1)
        dT2=np.append(dT2,iT2)
#             dT3=np.append(dT3,iT3)

Ptotsfi=Ptotsi.flatten()
Trefsfi=Trefsi.flatten()

# print '2d index', np.asarray(np.unravel_index(Ptots.argmax(), Ptots.shape))
opt_indexi= np.asarray(np.unravel_index(Ptotsi.argmax(), Ptotsi.shape))
print opt_indexi
Gainpoweri= 100*((max(Ptotsfi)-Pref)/max(Ptotsfi))
# print Trefs[:,opt_index[0],opt_index[1]]


# print dT1.shape
print 'Maximum power from optimization %4.2f/ max CP power %4.2f' %(max(Ptotsfi) , Pref)
# print 'index', np.argmax(Ptotsf)
print 'Derating T1 at max power', dT1[np.argmax(Ptotsfi)]
print 'Derating T2 at max power', dT2[np.argmax(Ptotsfi)]
print 'Derating T1 at max cp', Tref[0]/WT.P_rated
print 'Derating T2 at max cp', Tref[1]/WT.P_rated
print 'percentage of derating T1 at max power', 100*((Tref[0]/WT.P_rated-dT1[np.argmax(Ptotsfi)])/(Tref[0]/WT.P_rated))
print 'percentage of derating T2 at max power', 100*((Tref[1]/WT.P_rated-dT2[np.argmax(Ptotsfi)])/(Tref[1]/WT.P_rated))
print 'Power yield gained from derating in %', Gainpoweri
print ' .... Power produced by 3 turbines at standard', Tref
print ' .... .Optimized power producted by 3 turbines', Trefsi[:,opt_indexi[0],opt_indexi[1]]
# Out:
# [7 8]
# Maximum power from optimization 2239.26/ max CP power 2128.21
# Derating T1 at max power 0.577654849666
# Derating T2 at max power 0.203464399195
# Derating T1 at max cp 0.602949832962
# Derating T2 at max cp 0.181627110217
# percentage of derating T1 at max power 4.19520529128
# percentage of derating T2 at max power -12.0231439856
# Power yield gained from derating in % 4.95922760198
#  .... Power produced by 3 turbines at standard [ 1386.81   417.75   323.65]
#  .... .Optimized power producted by 3 turbines [ 1328.56   468.     442.7 ]

# %%
# # for iP in vDe:
# p = figure(plot_width=400, plot_height=400)
# p.line(vT1,Trefsi[0,:,0])    
# p.circle(vT1,Trefsi[0,:,0], fill_color="white", size=8) 
# p.line(vT1,Trefsi[1,0,:], color="olive")
# p.circle(vT1,Trefsi[1,0,:], color="olive",fill_color="white", size=8) 
# p.line(vT1,Trefsi[2,0,:], color="red")
# p.circle(vT1,Trefsi[2,0,:], color="red",fill_color="white", size=8) 
# p.line(vT1,Ptotsi[0,:], color="red")
# p.circle(vT1,Ptotsi[0,:], color="red",fill_color="white", size=8) 
# bokeh.plotting.show(p)

plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
CS=plt.contourf(100.*((vT1-dmax[0])/vT1),100.*((vT2-dmax[1])/vT2),100.*((Trefsi[2,:,:].T-Tref[2])/Trefsi[2,:,:].T),75)
CS2 = plt.contour(CS, levels=CS.levels[::3],
                  colors='k',
                  hold='on')
plt.plot(100*((dT1[np.argmax(Ptotsfi)]-Tref[0]/WT.P_rated)/(dT1[np.argmax(Ptotsfi)])),100*((dT2[np.argmax(Ptotsfi)]-Tref[1]/WT.P_rated)/(dT2[np.argmax(Ptotsfi)])),'wo',markersize=10)
plt.xlabel('Derating T1 [%]')
plt.ylabel('Derating T2 [%]')
plt.title('T3 - variation of power production %')
plt.colorbar(CS)

plt.subplot(1,3,2)
CS=plt.contourf(100.*((vT1-dmax[0])/vT1),100.*((vT2-dmax[1])/vT2),100.*((Trefsi[1,:,:].T-Tref[1])/Trefsi[1,:,:].T),75)
CS2 = plt.contour(CS, levels=CS.levels[::3],
                  colors='k',
                  hold='on')
plt.plot(100*((dT1[np.argmax(Ptotsfi)]-Tref[0]/WT.P_rated)/(dT1[np.argmax(Ptotsfi)])),100*((dT2[np.argmax(Ptotsfi)]-Tref[1]/WT.P_rated)/(dT2[np.argmax(Ptotsfi)])),'wo',markersize=10)
plt.xlabel('Derating T1 [%]')
plt.ylabel('Derating T2 [%]')
plt.title('T2 - variation of power production %')
plt.colorbar(CS)

plt.subplot(1,3,3)
CS=plt.contourf(100.*((vT1-dmax[0])/vT1),100.*((vT2-dmax[1])/vT2),100.*((Trefsi[0,:,:].T-Tref[0])/Trefsi[0,:,:].T),75)
CS2 = plt.contour(CS, levels=CS.levels[::3],
                  colors='k',
                  hold='on')
plt.plot(100*((dT1[np.argmax(Ptotsfi)]-Tref[0]/WT.P_rated)/(dT1[np.argmax(Ptotsfi)])),100*((dT2[np.argmax(Ptotsfi)]-Tref[1]/WT.P_rated)/(dT2[np.argmax(Ptotsfi)])),'wo',markersize=10)
plt.xlabel('Derating T1 [%]')
plt.ylabel('Derating T2 [%]')
plt.title('T1 - variation of power production %')
plt.colorbar(CS)

plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
CS=plt.contourf(100.*((vT1-dmax[0])/vT1),100.*((vT2-dmax[1])/vT2),100.*((Ptotsi.T-Pref)/Ptotsi.T),75)
CS2 = plt.contour(CS, levels=CS.levels[::4],
                  colors='k',
                  hold='on')
plt.plot(100*((dT1[np.argmax(Ptotsfi)]-Tref[0]/WT.P_rated)/(dT1[np.argmax(Ptotsfi)])),100*((dT2[np.argmax(Ptotsfi)]-Tref[1]/WT.P_rated)/(dT2[np.argmax(Ptotsfi)])),'wo',markersize=10)
plt.plot(0,0,'mo',markersize=10)
plt.xlabel('Derating T1 [%]')
plt.ylabel('Derating T2 [%]')
plt.title('Farm power production - variation of power production %')
plt.colorbar(CS)



plt.subplot(1,2,2)
CS=plt.contourf(100.*((vT1-dmax[0])/vT1),100.*((vT2-dmax[1])/vT2),Pitchsi[1,:,:].T,75)
CS2 = plt.contour(CS, levels=CS.levels[::3],
                  colors='k',
                  hold='on')
plt.plot(100*((dT1[np.argmax(Ptotsfi)]-Tref[0]/WT.P_rated)/(dT1[np.argmax(Ptotsfi)])),100*((dT2[np.argmax(Ptotsfi)]-Tref[1]/WT.P_rated)/(dT2[np.argmax(Ptotsfi)])),'wo',markersize=10)
plt.xlabel('Derating T1 [%]')
plt.ylabel('Derating T2 [%]')
plt.title('T2 - variation of pitch angle deg')
plt.colorbar(CS)

# fig = plt.figure(figsize=(15, 10))
# ax = Axes3D(fig)
# X,Y=np.meshgrid( 100*((Tref[0]/WT.P_rated-vT1)/(Tref[0]/WT.P_rated)), 100*((Tref[1]/WT.P_rated-vT2)/(Tref[1]/WT.P_rated)))
# # X,Y=np.meshgrid(vT1,vT2)
# surf=ax.plot_surface( X,Y,100.*((Ptotsi.T-Pref)/Ptotsi.T), rstride=1, cstride=1, cmap=cm.gist_ncar,
#         linewidth=0.5, antialiased=True,shade=True)
# # ax.scatter(100*((Tref[0]/WT.P_rated-dT1[np.argmax(Ptotsf)])/(Tref[0]/WT.P_rated)),100*((Tref[1]/WT.P_rated-dT2[np.argmax(Ptotsf)])/(Tref[1]/WT.P_rated)),100*((max(Ptotsf)-Pref)/max(Ptotsf)), color='k',marker='o',s=200)
# # ax.set_zlim(0., 0.5)
# ax.set_xlabel('Derating T1 [%]',fontsize=16)
# ax.set_ylabel('Derating T2 [%]',fontsize=16)
# ax.set_zlabel('T1-2-3 power production increase [%]',fontsize=16)
# ax.zaxis.set_major_locator(LinearLocator(1))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# plt.colorbar(surf, shrink=0.40, fraction=0.15,aspect=5)

# %%
# # look at pitch and RPM
plt.figure(figsize=(15,15))
plt.subplot(3,3,1)
plt.plot([1.,2.,3.],Tref/Tref[0],'bo-')
plt.plot([1.,2.,3.],Trefsi[:,opt_indexi[0],opt_indexi[1]]/Tref[0],'ko-')
plt.grid('on')

plt.subplot(3,3,2)
plt.plot([1.,2.,3.],Tref,'bo-')
plt.plot([1.,2.,3.],Trefsi[:,opt_indexi[0],opt_indexi[1]],'ko-')
plt.grid('on')

plt.subplot(3,3,3)
plt.plot([1.,2.,3.],Vel_outref,'bo-')
plt.plot([1.,2.,3.],Vels_outi[:,opt_indexi[0],opt_indexi[1]],'ko-')
plt.grid('on')

plt.subplot(3,3,4)
plt.plot([1.,2.,3.],Pitchref,'bo-')
plt.plot([1.,2.,3.],Pitchsi[:,opt_indexi[0],opt_indexi[1]],'ko-')

plt.grid('on')
