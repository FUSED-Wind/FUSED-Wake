# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload
import numpy as np
import scipy as sp
import pandas as pd
from scipy import interpolate
import matplotlib.pyplot as plt

import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
sys.path.append(parentdir+'/gclarsen/src/gclarsen')

topparentdir = os.path.dirname(parentdir)
sys.path.insert(0,topparentdir) 
sys.path.append(topparentdir+'/fusedwind/src/fusedwind')
print topparentdir

import fusedwind

import WindTurbine as wt
import WindFarm as wf
import fused as fused_gcl
from GCLarsen import *
# Out:
# /Users/JPM/Documents/PhD/Models
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-119b9596abe4> in <module>()
#      23 import WindTurbine as wt
#      24 import WindFarm as wf
# ---> 25 import fused as fused_gcl
#      26 from GCLarsen import *
#
# /Users/JPM/Documents/PhD/Models/FUSED-Wake/gclarsen/src/gclarsen/fused.py in <module>()
#       3 __all__ = ['FGCLarsen']
#       4
# ----> 5 from fusedwind.plant_flow.comp import GenericWindFarm
#       6 from fusedwind.interface import implement_base
#       7 from fusedwind.plant_flow.vt import GenericWindFarmTurbineLayout,\
#
# ImportError: No module named plant_flow.comp

# %%
import fusedwind.plant_flow.comp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-9e2eef417533> in <module>()
# ----> 1 import fusedwind.plant_flow.comp
#
# ImportError: No module named plant_flow.comp

# %%
from fusedwasp import  PlantFromWWH
#wwh = PlantFromWWH(filename = parentdir+'/wind-farm-wake-model/gclarsen/src/gclarsen/test/wind_farms/horns_rev/hornsrev1_turbine_nodescription.wwh')
wwh = PlantFromWWH(filename = parentdir+'/wind-farm-wake-model/gclarsen/src/gclarsen/test/wind_farms/horns_rev/windfarm-V10.wwh')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-d6222aaff283> in <module>()
#       1 from fusedwasp import  PlantFromWWH
#       2 #wwh = PlantFromWWH(filename = parentdir+'/wind-farm-wake-model/gclarsen/src/gclarsen/test/wind_farms/horns_rev/hornsrev1_turbine_nodescription.wwh')
# ----> 3 wwh = PlantFromWWH(filename = parentdir+'/wind-farm-wake-model/gclarsen/src/gclarsen/test/wind_farms/horns_rev/windfarm-V10.wwh')
#
# /Users/JPM/Documents/PhD/Models/wind-farm-wake-model/gclarsen/src/gclarsen/fusedwasp.pyc in __init__(self, filename)
#      94         if filename is not None:
#      95             self.filename = filename
# ---> 96             self.execute()
#      97
#      98     def execute(self):
#
# /Users/JPM/Documents/PhD/Models/wind-farm-wake-model/gclarsen/src/gclarsen/fusedwasp.pyc in execute(self)
#      98     def execute(self):
#      99         # Reading the .wwf file
# --> 100         wwh = WWH(self.filename)
#     101
#     102         for wt, data in wwh.wind_turbines.iteritems():
#
# /Users/JPM/Documents/PhD/Models/py4we/we_file_io.py in __init__(self, filename, file_type_name, file_extension)
#      33             self.filename = filename
#      34             ### If the filename is provided, read the file
# ---> 35             self.read()
#      36
#      37
#
# /Users/JPM/Documents/PhD/Models/py4we/we_file_io.py in read(self, filename)
#      53
#      54         if self.filename:
# ---> 55             self._read()
#      56             #return self.data
#      57         else:  # If self.filename == None, raise an exception
#
# /Users/JPM/Documents/PhD/Models/py4we/wasp.py in _read(self)
#     198         for ts in turbine_sites:
#     199             ### Get the wind turbine description
# --> 200             turbine_xml = xmlf(ts, 'Wind turbine generator', 'ChildMembers/WaspHierarchyMember')[0].find('MemberData/WindTurbineGenerator')
#     201             a = np.array(list(map(datapoint, turbine_xml.findall('PerformanceTable/DataTable/DataPoint'))))
#     202             ## Sorting with respect of wind speed
#
# IndexError: list index out of range

# %% [markdown]
# ## Verification of the FUSED-Wind wrapper

# %% [markdown]
# common inputs

# %%
v80 = wt.WindTurbine('Vestas v80 2MW offshore','V80_2MW_offshore.dat',70,40)
HR1 = wf.WindFarm('Horns Rev 1','HR_coordinates.dat',v80)
WD = range(0,360,1)

# %% [markdown]
# FUSED-Wind implementation

# %%
##Fused inputs
inputs = dict(
    wind_speed=8.0,
    roughness=0.0001,
    TI=0.05,
    NG=4,
    sup='lin',
    wt_layout = fused_gcl.generate_GenericWindFarmTurbineLayout(HR1))

fgcl = fused_gcl.FGCLarsen()
# Setting the inputs
for k,v in inputs.iteritems():
    setattr(fgcl, k, v)

fP_WF = np.zeros([len(WD)])
for iwd, wd in enumerate(WD):
    fgcl.wind_direction = wd
    fgcl.run()
    fP_WF[iwd] = fgcl.power

# %% [markdown]
# pure python implementation

# %%
P_WF = np.zeros([len(WD)])
for iwd, wd in enumerate(WD):
    P_WT,U_WT,CT_WT = GCLarsen(U0=8.0,z0=0.0001,TI=0.05,cWD=wd,WF=HR1,NG=4,sup='lin')
    P_WF[iwd] = P_WT.sum()

# %%
fig, ax = plt.subplots()
ax.plot(WD,P_WF/(HR1.WT.get_P(8.0)*HR1.nWT),'-o', label='Pure python')
ax.plot(WD,fP_WF/(HR1.WT.get_P(8.0)*HR1.nWT),'-d', label='FUSED wrapper')
ax.set_xlabel('wd [deg]')
ax.set_ylabel('Wind farm efficiency [-]')
ax.set_title(HR1.name)
ax.legend(loc=3)
plt.savefig(HR1.name+'_Power_wd_360.pdf')

# %% [markdown]
# ## Asserting new implementation

# %%
WD = 261.05
P_WT,U_WT,CT_WT = GCLarsen(U0=10.,z0=0.0001,TI=0.1,cWD=WD,WF=HR1, NG=5, sup='quad')
P_WT_2,U_WT_2,CT_WT_2 = GCLarsen_v2(U0=10.,z0=0.0001,TI=0.1,cWD=WD,WF=HR1, NG=5, sup='quad')

# %%
np.testing.assert_array_almost_equal(U_WT,U_WT_2)
np.testing.assert_array_almost_equal(P_WT,P_WT_2)

# %% [markdown]
# ## Time comparison

# %% [markdown]
# New implementation is wrapped inside fusedwind

# %%
WD = range(0,360,1)

# %%
# %%timeit
fP_WF = np.zeros([len(WD)])
for iwd, wd in enumerate(WD):
    fgcl.wind_direction = wd
    fgcl.run()
    fP_WF[iwd] = fgcl.power
# Out:
# 1 loops, best of 3: 6.39 s per loop

# %%
# %%timeit
#%%prun -s cumulative #profiling
P_WF = np.zeros([len(WD)])
for iwd, wd in enumerate(WD):
    P_WT,U_WT,CT_WT = GCLarsen(U0=8.0,z0=0.0001,TI=0.05,cWD=wd,WF=HR1,NG=4,sup='lin')
    P_WF[iwd] = P_WT.sum()
# Out:
# 1 loops, best of 3: 18.7 s per loop

# %% [markdown]
# ## Pandas

# %%
df=pd.DataFrame(data=P_WF, index=WD, columns=['P_WF'])

# %%
df.plot()

# %% [markdown]
# # WD uncertainty

# %% [markdown]
# Normally distributed wind direction uncertainty (reference wind direction, not for individual turbines).

# %%
P_WF_GAv8 = np.zeros([len(WD)])
P_WF_GAv16 = np.zeros([len(WD)])
for iwd, wd in enumerate(WD):
    P_WT_GAv,U_WT,CT_WT = GCL_P_GaussQ_Norm_U_WD(meanWD=wd,stdWD=2.5,NG_P=8, U0=8.0,z0=0.0001,TI=0.05,WF=HR1,NG=4,sup='lin')
    P_WF_GAv8[iwd] = P_WT_GAv.sum()
    P_WT_GAv,U_WT,CT_WT = GCL_P_GaussQ_Norm_U_WD(meanWD=wd,stdWD=2.5,NG_P=16, U0=8.0,z0=0.0001,TI=0.05,WF=HR1,NG=4,sup='lin')
    P_WF_GAv16[iwd] = P_WT_GAv.sum()

# %%
fig, ax = plt.subplots()
fig.set_size_inches([12,6])
ax.plot(WD,P_WF/(HR1.WT.get_P(8.0)*HR1.nWT),'-o', label='Pure python')
ax.plot(WD,fP_WF/(HR1.WT.get_P(8.0)*HR1.nWT),'-d', label='FUSED wrapper')
ax.plot(WD,P_WF_GAv16/(HR1.WT.get_P(8.0)*HR1.nWT),'-', label='Gauss Avg. FUSED wrapper, NG_P = 16')
ax.plot(WD,P_WF_GAv8/(HR1.WT.get_P(8.0)*HR1.nWT),'-', label='Gauss Avg. FUSED wrapper, NG_P = 8')
ax.set_xlabel('wd [deg]')
ax.set_ylabel('Wind farm efficiency [-]')
ax.set_title(HR1.name)
ax.legend(loc=3)
plt.savefig(HR1.name+'_Power_wd_360.pdf')

# %% [markdown]
# Uniformly distributed wind direction uncertainty (bin/sectors definition)

# %%
P_WF_GA_u8 = np.zeros([len(WD)])
for iwd, wd in enumerate(WD):
    P_WT_GAv,U_WT,CT_WT = GCL_P_GaussQ_Uni_U_WD(meanWD=wd,U_WD=2.5,NG_P=8, U0=8.0,z0=0.0001,TI=0.05,WF=HR1,NG=4,sup='lin')
    P_WF_GA_u8[iwd] = P_WT_GAv.sum()

# %%
fig, ax = plt.subplots()
fig.set_size_inches([12,6])
ax.plot(WD,fP_WF/(HR1.WT.get_P(8.0)*HR1.nWT),'-d', label='FUSED wrapper')
ax.plot(WD,P_WF_GAv8/(HR1.WT.get_P(8.0)*HR1.nWT),'-', label='Gauss Quad. Normal, NG_P = 8')
ax.plot(WD,P_WF_GA_u8/(HR1.WT.get_P(8.0)*HR1.nWT),'-', label='Gauss Quad. Uniform, NG_P = 8')
ax.set_xlabel('wd [deg]')
ax.set_ylabel('Wind farm efficiency [-]')
ax.set_title(HR1.name)
ax.legend(loc=3)
plt.savefig(HR1.name+'_Power_wd_360.pdf')
